# %% [markdown]
# # Variable Features Plots

# %%
import warnings
warnings.filterwarnings('ignore')
    
import os
import traceback
import sys

sys.path.append(os.path.abspath(os.path.join('.')))
sys.path.append(os.path.abspath(os.path.join('..')))

import pandas as pd
import numpy as np 
# %matplotlib inline
import matplotlib.pyplot as plt
from visualization.plots import top_plots

# %%
# ds_names = ['CLL_SUB_111', 'CNS', 'colon', 'GLI_85', 'GLIOMA', 'Leukemia', 'lung', 
#             'Lymphoma', 'MLL', 'ovarian', 'Prostate_GE', 'SRBCT', 'TOX_171']

# subsets = ['JACKSTRAW', 'CFS', 'EN', 'LASSO', 'SS']
# removed = ['SCA', 'MRMR']

# %%
ds_names = ['CLL_SUB_111', 'CNS', 'colon', 'GLI_85', 'GLIOMA', 'Leukemia', 'lung', 
            'Lymphoma', 'MLL', 'ovarian', 'Prostate_GE', 'SRBCT', 'TOX_171']

top_algs = [['SVM-RFE', 'BORUTA', 'EN', 'LASSO', 'JACKSTRAW'], 
            ['JACKSTRAW', 'CFS', 'IG', 'TSFS', 'SS'],
            ['TSFS', 'LDA', 'CFS', 'MRMR', 'IG'],
            ['RELIEFF', 'IG', 'JACKSTRAW', 'SS', 'BORUTA'],
            ['RELIEFF', 'BORUTA', 'SVM-RFE', 'CFS', 'EN'],
            ['JACKSTRAW', 'RELIEFF', 'IG', 'BORUTA', 'EN'],
            ['EN', 'MLP', 'IG', 'RELIEFF', 'BORUTA'],
            ['TSFS', 'RELIEFF', 'LDA', 'MRMR', 'HSIC'],
            ['SVM-RFE', 'MLP', 'IG', 'BORUTA', 'MCFS'],
            ['SVM-RFE', 'LASSO', 'EN', 'CFS', 'MLP'],
            ['IG', 'RELIEFF', 'CFS', 'SVM-RFE', 'MLP'],
            ['SVM-RFE', 'RELIEFF', 'IG', 'JACKSTRAW', 'BORUTA'],
            ['RELIEFF', 'IG', 'MCFS', 'MLP', 'EN']]
positions = [[12, 2, 14, 14, 10], 
             [6, 8, 14, 2, 13],
             [8, 9, 11, 6, 10],
             [9, 3, 4, 9, 9],
             [12, 12, 14, 13, 13],
             [12, 3, 6, 4, 8],
             [12, 13, 12, 14, 13],
             [5, 4, 13, 6, 9],
             [10, 12, 12, 6, 14],
             [1, 2, 2, 11, 10],
             [9, 11, 12, 11, 14],
             [6, 6, 8, 9, 10],
             [13, 14, 11, 12, 5]]
             

for ds_name, algs, pos in zip(ds_names, top_algs, positions):
    top_plots(ds_name, algs, pos)
# Out:
# No handles with labels found to put in legend.

# %%
top_plots('MLL', ['SVM-RFE', 'MLP', 'IG', 'BORUTA', 'MCFS'])
