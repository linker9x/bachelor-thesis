# %% [markdown]
# # Example Book

# %%
import warnings
warnings.filterwarnings('ignore')
    
import os
import traceback
import sys

sys.path.append(os.path.abspath(os.path.join('..')))
sys.path.append(os.path.abspath(os.path.join('.')))

import pandas as pd
pd.set_option('display.max_rows', 1000)
import numpy as np 
# %matplotlib inline
import matplotlib.pyplot as plt

from experiments.ba_experiment import run_multi_experiment
# Out:
# Using TensorFlow backend.

# %%
num_feats = [5, 10, 15, 20, 25, 35, 45, 55, 65, 75, 125, 150, 175, 200, 250]

# returns unranked subset - (think)
# alg_names = ['JACKSTRAW', 'CFS']

#returns ranked subset - (think)
# alg_names = ['EN', 'LASSO', 'SS']

# returns param amount of feats - return 1 to 275
alg_names = ['MRMR', 'CHI2', 'CAE', 'HSIC']

# returns all features ranked - return 1 to 275
# alg_names = ['IG', 'LDA', 'MCFS', 'RELIEFF', 'BORUTA', 'SVM-RFE', 'MLP', 'SCA', 'DBN', 'TSFS']


ds_names = ['colon', 'GLI_85']
# ds_names = ['SMK_CAN_187', 'Lymphoma']
# ds_names = ['lung', 'GLIOMA']
# ds_names = ['MLL', 'TOX_171']
# ds_names = ['CLL_SUB_111', 'Prostate_GE']
# ds_names = ['CNS', 'Leukemia']

# %%
run_multi_experiment(alg_names, ds_names, num_feats)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# I0729 14:26:47.218637  1112 jvm.py:83] Adding bundled jars
# I0729 14:26:47.221634  1112 jvm.py:90] Classpath=['C:\\Users\\linker\\Miniconda3\\envs\\deepl\\lib\\site-packages\\javabridge\\jars\\rhino-1.7R4.jar', 'C:\\Users\\linker\\Miniconda3\\envs\\deepl\\lib\\site-packages\\javabridge\\jars\\runnablequeue.jar', 'C:\\Users\\linker\\Miniconda3\\envs\\deepl\\lib\\site-packages\\javabridge\\jars\\cpython.jar', 'C:\\Users\\linker\\Miniconda3\\envs\\deepl\\lib\\site-packages\\weka\\lib\\python-weka-wrapper.jar', 'C:\\Users\\linker\\Miniconda3\\envs\\deepl\\lib\\site-packages\\weka\\lib\\weka.jar']
# I0729 14:26:47.222634  1112 jvm.py:91] MaxHeapSize=default
# I0729 14:26:47.224632  1112 jvm.py:100] Package support disabled
# MRMR: colon
# X.shape:  (62, 2000)
# y.shape:  (62,)
# X.shape:  (62, 2000)
# y.shape:  (62,)
# Fold No: 0
#
# No. Feats: 5
#
# Subset/Param
# No. Feats: 10
#
# Subset/Param
# No. Feats: 15
#
# Subset/Param
# No. Feats: 20
#
# Subset/Param
# No. Feats: 25
#
# Subset/Param
# No. Feats: 35
#
# Subset/Param
# No. Feats: 45
#
# Subset/Param
# No. Feats: 55
#
# Subset/Param
# No. Feats: 65
#
# Subset/Param
# No. Feats: 75
#
# Subset/Param
# No. Feats: 125
#
# Subset/Param
# No. Feats: 150
#
# Subset/Param
# No. Feats: 175
#
# Subset/Param
# No. Feats: 200
#
# Subset/Param
# No. Feats: 250
#
# Subset/Param
# Fold No: 1
#
# No. Feats: 5
#
# Subset/Param
# No. Feats: 10
#
# Subset/Param
# No. Feats: 15
#
# Subset/Param
# No. Feats: 20
#
# Subset/Param
# No. Feats: 25
#
# Subset/Param
# No. Feats: 35
#
# Subset/Param
# No. Feats: 45
#
# Subset/Param
# No. Feats: 55
#
# Subset/Param
# No. Feats: 65
#
# Subset/Param
# No. Feats: 75
#
# Subset/Param
# No. Feats: 125
#
# Subset/Param
# No. Feats: 150
#
# Subset/Param
# No. Feats: 175
#
# Subset/Param
# No. Feats: 200
#
# Subset/Param
# No. Feats: 250
#
# Subset/Param
# Fold No: 2
#
# No. Feats: 5
#
# Subset/Param
# No. Feats: 10
#
# Subset/Param
# No. Feats: 15
#
# Subset/Param
# No. Feats: 20
#
# Subset/Param
# No. Feats: 25
#
# Subset/Param
# No. Feats: 35
#
# Subset/Param
# No. Feats: 45
#
# Subset/Param
# No. Feats: 55
#
# Subset/Param
# No. Feats: 65
#
# Subset/Param
# No. Feats: 75
#
# Subset/Param
# No. Feats: 125
#
# Subset/Param
# No. Feats: 150
#
# Subset/Param
# No. Feats: 175
#
# Subset/Param
# No. Feats: 200
#
# Subset/Param
# No. Feats: 250
#
# Subset/Param
# Fold No: 3
#
# No. Feats: 5
#
# Subset/Param
# No. Feats: 10
#
# Subset/Param
# No. Feats: 15
#
# Subset/Param
# No. Feats: 20
#
# Subset/Param
# No. Feats: 25
#
# Subset/Param
# No. Feats: 35
#
# Subset/Param
# No. Feats: 45
#
# Subset/Param
# No. Feats: 55
#
# Subset/Param
# No. Feats: 65
#
# Subset/Param
# No. Feats: 75
#
# Subset/Param
# No. Feats: 125
#
# Subset/Param
# No. Feats: 150
#
# Subset/Param
# No. Feats: 175
#
# Subset/Param
# No. Feats: 200
#
# Subset/Param
# No. Feats: 250
#
# Subset/Param
# Fold No: 4
#
# No. Feats: 5
#
# Subset/Param
# No. Feats: 10
#
# Subset/Param
# No. Feats: 15
#
# Subset/Param
# No. Feats: 20
#
# Subset/Param
# No. Feats: 25
#
# Subset/Param
# No. Feats: 35
#
# Subset/Param
# No. Feats: 45
#
# Subset/Param
# No. Feats: 55
#
# Subset/Param
# No. Feats: 65
#
# Subset/Param
# No. Feats: 75
#
# Subset/Param
# No. Feats: 125
#
# Subset/Param
# No. Feats: 150
#
# Subset/Param
# No. Feats: 175
#
# Subset/Param
# No. Feats: 200
#
# Subset/Param
# No. Feats: 250
#
# Subset/Param
# SAVING
# MRMR: GLI_85
# X.shape:  (85, 22283)
# y.shape:  (85,)
# X.shape:  (85, 22283)
# y.shape:  (85,)
# Fold No: 0
#
# No. Feats: 5
#
# Subset/Param
# No. Feats: 10
#
# Subset/Param
# No. Feats: 15
#
# Subset/Param
# No. Feats: 20
#
# Subset/Param
# No. Feats: 25
#
# Subset/Param
# No. Feats: 35
#
# Subset/Param
# No. Feats: 45
#
# Subset/Param
# No. Feats: 55
#
# Subset/Param
# No. Feats: 65
#
# Subset/Param
# No. Feats: 75
#
# Subset/Param
# No. Feats: 125
#
# Subset/Param
